# %% [markdown]
# # Program to calculate the proper deposit ammounts for a given token

# %%
import cl_classes as cl
import pandas as pd
import unimath

amount = 10000
token1_price = 98000
token2_price = 3200
token1_ratio = 0.6
token2_ratio = 1 - token1_ratio
# Out:
# Getting Info for base pair 0x70aCDF2Ad0bf2402C957154f944c19Ef4e1cbAE1
# Getting historical in_data for coinbase-wrapped-btc
# Try #1
# ---------------------------------------------------------------------------
# InsufficientDataBytes                     Traceback (most recent call last)
# File ~/Documents/SourceCode/concentratedLiquidity/.venv/lib/python3.11/site-packages/web3/contract/utils.py:111, in call_contract_function(w3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     110 try:
# --> 111     output_data = w3.codec.decode(output_types, return_data)
#     112 except DecodingError as e:
#     113     # Provide a more helpful error message than the one provided by
#     114     # eth-abi-utils
#
# File ~/Documents/SourceCode/concentratedLiquidity/.venv/lib/python3.11/site-packages/eth_abi/codec.py:162, in ABIDecoder.decode(self, types, data, strict)
# ...
